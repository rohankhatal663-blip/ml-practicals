# %%
Name:- rohan khatal
Roll_No:- 13234

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\pradip kale\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\pradip kale\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\pradip kale\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pradip kale\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\pradip kale\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\pradip kale\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
import re
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt') 
nltk.download('stopwords') 
nltk.download('wordnet') 
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Pradip
# [nltk_data]     Kale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Pradip
# [nltk_data]     Kale\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Pradip
# [nltk_data]     Kale\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Pradip Kale\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Pradip
# [nltk_data]     Kale\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Pradip
# [nltk_data]     Kale\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
text="Tokenization is the first step in text analytics.The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization."

# %%
from nltk.tokenize import sent_tokenize

tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Tokenization is the first step in text analytics.The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization.']

# %%
# Step 3: Word Tokenization
from nltk.tokenize import word_tokenize

tokenized_word = word_tokenize(text)
print("\nWord Tokenization:")
print(tokenized_word)
# Out:
# Word Tokenization:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics.The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
# Step 4: Removing Punctuations and Stop Words
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))
print("\nStop Words:")
print(stop_words)

# Remove punctuation
clean_text = re.sub('[^a-zA-Z]', ' ', text)

tokens = word_tokenize(clean_text.lower())

filtered_text = []
for w in tokens:
    if w not in stop_words:
        filtered_text.append(w)

print("\nTokenized Sentence:", tokens)
print("Filtered Sentence:", filtered_text)
# Out:
# Stop Words:
# {'them', 'weren', 'has', 'in', 'once', 'themselves', 'very', 'hers', "hadn't", 'itself', 'wasn', 'down', 'between', 'didn', 'shan', "wasn't", "needn't", 'mustn', "i'm", 'you', "doesn't", 'don', 'll', 'an', "i'd", 'myself', 'those', 'your', "mightn't", "wouldn't", "we've", "he's", 'won', "it's", 'about', 'as', 'her', 'any', 'isn', 'only', "we'll", 'its', 'all', "i've", "didn't", 'are', 'have', 'nor', "she'll", "she'd", 'that', "we're", "should've", 'each', 'same', 'she', "haven't", "you'd", 'me', 've', 'to', 'been', 'yours', 'my', 'being', "it'll", "hasn't", 'we', 'off', 'whom', "aren't", 'is', 'of', 'on', 'shouldn', 'now', "you're", 'through', "it'd", "weren't", 'under', 'who', 'such', 'at', 'what', 'during', 'will', 'and', 'before', 'was', 'while', 'can', 'needn', 'some', 'over', 'the', 'hasn', 'yourself', 'than', 't', 'wouldn', 'having', 'if', 'himself', "shan't", 'this', 'until', "don't", 'ours', 'were', 'mightn', 'because', 'why', 'doesn', 'there', 'how', 'most', 'their', 'yourselves', 'i', "shouldn't", 'theirs', 'above', 'him', 's', 'so', 'haven', "they've", 'these', "they'd", 'out', 'not', 'or', 'd', 'aren', 'more', 'it', "they'll", 'his', 'which', "we'd", 'here', 'ain', 'ma', 'he', 'herself', 'where', 'with', 'y', 'against', 'by', 'does', 'no', 'after', 'did', "mustn't", 'both', 'too', 'be', "that'll", "he'd", "won't", "you've", 'm', 'below', 'but', 'for', 'had', 'into', 'when', 'then', 'they', "couldn't", 'our', 'ourselves', 'other', 'am', 'hadn', "i'll", 'do', "isn't", 'should', 'again', 'few', 're', 'up', "she's", 'couldn', 'doing', 'a', 'further', 'o', 'just', "you'll", "he'll", 'own', 'from', "they're"}
#
# Tokenized Sentence: ['tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', 'the', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'tokenization']
# Filtered Sentence: ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %%
# Step 5: Stemming
from nltk.stem import PorterStemmer

ps = PorterStemmer()
e_words = ["wait", "waiting", "waited", "waits"]

print("\nStemming:")
for w in e_words:
    rootWord = ps.stem(w)
    print(w, "->", rootWord)
# Out:
# Stemming:
# wait -> wait
# waiting -> wait
# waited -> wait
# waits -> wait

# %%
# Step 6: Lemmatization
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

text2 = "studies studying cries cry"
tokens2 = word_tokenize(text2)

print("\nLemmatization:")
for w in tokens2:
    print(f"{w} -> {wordnet_lemmatizer.lemmatize(w)}")
# Out:
# Lemmatization:
# studies -> study
# studying -> studying
# cries -> cry
# cry -> cry

# %%
# Step 7: POS Tagging
from nltk.tokenize import word_tokenize

data = "The pink sweater fit her perfectly"
words = word_tokenize(data)

print("\nPOS Tagging:")
for word in words:
    print(nltk.pos_tag([word]))
# Out:
# POS Tagging:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %%
# Step 1: Import necessary libraries
import pandas as pd
import math

# %%
# Step 2: Initialize Documents
documentA = 'Jupiter is the largest planet'
documentB = 'Mars is the fourth planet from the sun'

# %%
# Step 3: Create Bag of Words (BoW)
bagOfWordsA = documentA.split(' ')
bagOfWordsB = documentB.split(' ')

# %%
# Step 4: Create collection of unique words
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
# Step 5: Create word count dictionary for each document

numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
    numOfWordsA[word] += 1

numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
    numOfWordsB[word] += 1

# %%
# Step 6: Compute Term Frequency (TF)

def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
        
    return tfDict

tfA = computeTF(numOfWordsA, bagOfWordsA)
tfB = computeTF(numOfWordsB, bagOfWordsB)

# %%
# Step 7: Compute Inverse Document Frequency (IDF)

def computeIDF(documents):
    N = len(documents)
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    
    return idfDict

idfs = computeIDF([numOfWordsA, numOfWordsB])
print(idfs)
# Out:
# {'largest': 0.6931471805599453, 'planet': 0.0, 'Mars': 0.6931471805599453, 'sun': 0.6931471805599453, 'Jupiter': 0.6931471805599453, 'the': 0.0, 'fourth': 0.6931471805599453, 'is': 0.0, 'from': 0.6931471805599453}

# %%
# Step 8: Compute TF-IDF

def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    
    return tfidf

tfidfA = computeTFIDF(tfA, idfs)
tfidfB = computeTFIDF(tfB, idfs)

# %%
# Step 9: Display result in DataFrame

df = pd.DataFrame([tfidfA, tfidfB])
df
# Out:
#     largest  planet      Mars       sun   Jupiter  the    fourth   is  \
# 0  0.138629     0.0  0.000000  0.000000  0.138629  0.0  0.000000  0.0
# 1  0.000000     0.0  0.086643  0.086643  0.000000  0.0  0.086643  0.0
#
#        from
# 0  0.000000
# 1  0.086643
