# %%
NAME: rohan khatal
ROLL_NO: 13234
BATCH: B2

# %%
import pandas as pd

# %%
df=pd.read_csv("student_performance.csv")

# %%
df
# Out:
#     math-score  reading_score  writing_score  placement_score  club_join_year  \
# 0         60.0           92.0           65.0             98.0          2020.0
# 1         63.0           84.0           67.0             92.0          2019.0
# 2         76.0           79.0           60.0             87.0          2021.0
# 3         79.0           81.0           70.0            100.0          2018.0
# 4         72.0           77.0           64.0            100.0          2019.0
# 5         64.0           83.0           71.0             84.0          2020.0
# 6          NaN           80.0           75.0             90.0          2020.0
# 7         63.0           82.0           76.0             99.0          2018.0
# 8         63.0           83.0           76.0             92.0          2018.0
# 9         60.0           84.0           74.0             90.0          2018.0
# 10         NaN            NaN           79.0             76.0          2019.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   math-score       46 non-null     float64
#  1   reading_score    47 non-null     float64
#  2   writing_score    46 non-null     float64
#  3   placement_score  46 non-null     float64
#  4   club_join_year   46 non-null     float64
#  5   placement_offer  46 non-null     float64
# dtypes: float64(6)
# memory usage: 2.4 KB

# %%
df.isnull().sum()
# Out:
# math-score         3
# reading_score      2
# writing_score      3
# placement_score    3
# club_join_year     3
# placement_offer    3
# dtype: int64

# %%
df = df.rename(columns={"math-score": "math_score"})
df.math_score.max()
# Out:
# 200.0

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score  placement_score  \
# count   46.000000      47.000000      46.000000        46.000000
# mean    73.413043      86.893617      73.739130        87.934783
# std     20.095965      18.142233      19.862231         7.549546
# min     60.000000      75.000000      60.000000        75.000000
# 25%     64.250000      78.000000      67.000000        81.250000
# 50%     70.500000      84.000000      71.000000        88.500000
# 75%     77.000000      91.500000      76.000000        93.500000
# max    200.000000     200.000000     200.000000       100.000000
#
#        club_join_year  placement_offer
# count       46.000000        46.000000
# mean      2019.673913         2.630435
# std          1.174816         0.571886
# min       2018.000000         1.000000
# 25%       2019.000000         2.000000
# 50%       2019.500000         3.000000
# 75%       2021.000000         3.000000
# max       2021.000000         3.000000

# %%
x=df.math_score.mean()

# %%
print(x)
# Out:
# 73.41304347826087

# %%
df["math_score"] = df["math_score"].fillna(x)

# %%
df.fillna({"math_score": x}, inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    60.000000           92.0           65.0             98.0          2020.0
# 1    63.000000           84.0           67.0             92.0          2019.0
# 2    76.000000           79.0           60.0             87.0          2021.0
# 3    79.000000           81.0           70.0            100.0          2018.0
# 4    72.000000           77.0           64.0            100.0          2019.0
# 5    64.000000           83.0           71.0             84.0          2020.0
# 6    73.413043           80.0           75.0             90.0          2020.0
# 7    63.000000           82.0           76.0             99.0          2018.0
# 8    63.000000           83.0           76.0             92.0          2018.0
# 9    60.000000           84.0           74.0             90.0          2018.0
# 10   73.413043            NaN           79.0             76.0          2019.0
# ...

# %%
y=df.reading_score.mean()

# %%
df["reading_score"] = df["reading_score"].fillna(y)

# %%
df.fillna({"reading_score": y}, inplace=True)

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    60.000000      92.000000           65.0             98.0          2020.0
# 1    63.000000      84.000000           67.0             92.0          2019.0
# 2    76.000000      79.000000           60.0             87.0          2021.0
# 3    79.000000      81.000000           70.0            100.0          2018.0
# 4    72.000000      77.000000           64.0            100.0          2019.0
# 5    64.000000      83.000000           71.0             84.0          2020.0
# 6    73.413043      80.000000           75.0             90.0          2020.0
# 7    63.000000      82.000000           76.0             99.0          2018.0
# 8    63.000000      83.000000           76.0             92.0          2018.0
# 9    60.000000      84.000000           74.0             90.0          2018.0
# 10   73.413043      86.893617           79.0             76.0          2019.0
# ...

# %%
df=pd.read_csv("C:\Users\pradi\OneDrive\Desktop\stud_performance.csv")
# Out:
#   Cell In[9], line 1
#     df=pd.read_csv("C:\Users\pradi\OneDrive\Desktop\stud_performance.csv")
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv(r"C:\Users\pradi\OneDrive\Desktop\stud_performance.csv")

# %%
df
# Out:
#     math-score  reading_score  writing_score  placement_score  club_join_year  \
# 0         60.0           92.0           65.0             98.0          2020.0
# 1         63.0           84.0           67.0             92.0          2019.0
# 2         76.0           79.0           60.0             87.0          2021.0
# 3         79.0           81.0           70.0            100.0          2018.0
# 4         72.0           77.0           64.0            100.0          2019.0
# 5         64.0           83.0           71.0             84.0          2020.0
# 6          NaN           80.0           75.0             90.0          2020.0
# 7         63.0           82.0           76.0             99.0          2018.0
# 8         63.0           83.0           76.0             92.0          2018.0
# 9         60.0           84.0           74.0             90.0          2018.0
# 10         NaN            NaN           79.0             76.0          2019.0
# ...

# %%
z=df.writing_score.mean()

# %%
df["writing_score"] = df["writing_score"].fillna(z)

# %%
df
# Out:
#     math-score  reading_score  writing_score  placement_score  club_join_year  \
# 0         60.0           92.0       65.00000             98.0          2020.0
# 1         63.0           84.0       67.00000             92.0          2019.0
# 2         76.0           79.0       60.00000             87.0          2021.0
# 3         79.0           81.0       70.00000            100.0          2018.0
# 4         72.0           77.0       64.00000            100.0          2019.0
# 5         64.0           83.0       71.00000             84.0          2020.0
# 6          NaN           80.0       75.00000             90.0          2020.0
# 7         63.0           82.0       76.00000             99.0          2018.0
# 8         63.0           83.0       76.00000             92.0          2018.0
# 9         60.0           84.0       74.00000             90.0          2018.0
# 10         NaN            NaN       79.00000             76.0          2019.0
# ...

# %%
df.iloc[11:12,3:4].fillna(34,inplace=True)

# %%
df["club_join_year"] = df["club_join_year"].fillna(2019)

# %%
df
# Out:
#     math-score  reading_score  writing_score  placement_score  club_join_year  \
# 0         60.0           92.0       65.00000             98.0          2020.0
# 1         63.0           84.0       67.00000             92.0          2019.0
# 2         76.0           79.0       60.00000             87.0          2021.0
# 3         79.0           81.0       70.00000            100.0          2018.0
# 4         72.0           77.0       64.00000            100.0          2019.0
# 5         64.0           83.0       71.00000             84.0          2020.0
# 6          NaN           80.0       75.00000             90.0          2020.0
# 7         63.0           82.0       76.00000             99.0          2018.0
# 8         63.0           83.0       76.00000             92.0          2018.0
# 9         60.0           84.0       74.00000             90.0          2018.0
# 10         NaN            NaN       79.00000             76.0          2019.0
# ...

# %%
df["placement_score"] = df["placement_score"].fillna(222)

# %%
df
# Out:
#     math-score  reading_score  writing_score  placement_score  club_join_year  \
# 0         60.0           92.0       65.00000             98.0          2020.0
# 1         63.0           84.0       67.00000             92.0          2019.0
# 2         76.0           79.0       60.00000             87.0          2021.0
# 3         79.0           81.0       70.00000            100.0          2018.0
# 4         72.0           77.0       64.00000            100.0          2019.0
# 5         64.0           83.0       71.00000             84.0          2020.0
# 6          NaN           80.0       75.00000             90.0          2020.0
# 7         63.0           82.0       76.00000             99.0          2018.0
# 8         63.0           83.0       76.00000             92.0          2018.0
# 9         60.0           84.0       74.00000             90.0          2018.0
# 10         NaN            NaN       79.00000             76.0          2019.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(8)

# %%
df.columns
# Out:
# Index(['math-score', 'reading_score', 'writing_score', 'placement_score',
#        'club_join_year', 'placement_offer'],
#       dtype='object')

# %%
col=['math_score','reading_score','writing_score','placement_score','club_join_year','placement_offer']

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot(column="math-score")
# Out:
# <Axes: >

# %%
plt.show()

# %%
col1=['math-score','reading_score','writing_score','placement_score']

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
plt.scatterplot(placement_score,placement_offer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plt.scatterplot(placement_score,placement_offer)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scatterplot'

# %%
fig,ax=plt.subplots(figsize=(18,10))

# %%
ax.scatter(df['placement_score'],df['placement_offer'])

# %%
plt.show()

# %%
df.describe()
# Out:
#        math-score  reading_score  writing_score  placement_score  \
# count   46.000000      47.000000      49.000000        49.000000
# mean    73.413043      86.893617      73.739130        96.142857
# std     20.095965      18.142233      19.231522        33.286634
# min     60.000000      75.000000      60.000000        75.000000
# 25%     64.250000      78.000000      67.000000        82.000000
# 50%     70.500000      84.000000      73.000000        89.000000
# 75%     77.000000      91.500000      76.000000        95.000000
# max    200.000000     200.000000     200.000000       222.000000
#
#        club_join_year  placement_offer
# count       49.000000        46.000000
# mean      2019.632653         2.630435
# std          1.149164         0.571886
# min       2018.000000         1.000000
# 25%       2019.000000         2.000000
# 50%       2019.000000         3.000000
# 75%       2021.000000         3.000000
# max       2021.000000         3.000000

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('stud_performance.csv')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace('-', '_')

# %%
q1 = np.percentile(df['math_score'], 25)

# %%
print("25th percentile of math scores:", q1)
# Out:
# 25th percentile of math scores: nan

# %%
q3=np.percentile(df.math_score,75)

# %%
IQR=q3-q1

# %%
IQR
# Out:
# np.float64(nan)

# %%
upper_bod=q3+1.5*IQR

# %%
upper_bod
# Out:
# np.float64(nan)
